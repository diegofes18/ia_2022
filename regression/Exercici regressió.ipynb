# %% [markdown]
# # Exercici Regressió
#
# Farem una regressió multiple sobre un problema real. Emprarem el *California Housing* dataset.
#
# <img src="california.png"  width="500"/>
#
# >This dataset was obtained from the StatLib repository. https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
# >
# > **The target variable is the median house value for California districts, expressed in hundreds of thousands of dollars (100,000).**
# >
# >This dataset was derived from the 1990 U.S. census, using one row per census block group. A block group is the smallest geographical unit for which the U.S. Census Bureau publishes sample data (a block group typically has a population of 600 to 3,000 people).
# >
# >An household is a group of people residing within a home. Since the average number of rooms and bedrooms in this dataset are provided per household, these columns may take surpinsingly large values for block groups with few households and many empty houses, such as vacation resorts.
# >
# >It can be downloaded/loaded using the sklearn.datasets.fetch_california_housing function.
#
# Importam les llibreries que utilitzarem.

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# %% [markdown]
# Carregam les dades i realitzam una primera exploració inicial.

# %%
housing = fetch_california_housing(as_frame=True)

print(housing.keys())
df = housing.frame

df.head()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# Podem observar com es distribuixen les dades. ``Pandas`` té una funció que ens retorna informació estadística per cada una de les característiques.

# %% [markdown]
# # Treball vostre
#
# Fer un model de regressió lineal per prediure el valor de les cases a un barri (la darrera columna).

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
label = df.iloc[:,-1]
data = df.iloc[:,:-1]

# %%
label
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# 1        -122.22
# 2        -122.24
# 3        -122.25
# 4        -122.25
# ...          ...
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24
#
# [20640 rows x 8 columns]

# %%
corr= df.corr()
corr.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_2f977_row0_col0, #T_2f977_row1_col1, #T_2f977_row2_col2, #T_2f977_row3_col3, #T_2f977_row4_col4, #T_2f977_row5_col5, #T_2f977_row6_col6, #T_2f977_row7_col7, #T_2f977_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2f977_row0_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_2f977_row0_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_2f977_row0_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_2f977_row0_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_2f977_row0_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_2f977_row0_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_2f977_row0_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_2f977_row0_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_2f977_row1_col0, #T_2f977_row1_col2, #T_2f977_row1_col3, #T_2f977_row1_col4, #T_2f977_row4_col1, #T_2f977_row6_col7, #T_2f977_row6_col8, #T_2f977_row7_col6, #T_2f977_row8_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2f977_row1_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_2f977_row1_col6, #T_2f977_row3_col7 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_2f977_row1_col7, #T_2f977_row4_col6 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_2f977_row1_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_2f977_row2_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_2f977_row2_col1, #T_2f977_row4_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_2f977_row2_col3 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_2f977_row2_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_2f977_row2_col5, #T_2f977_row3_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_2f977_row2_col6 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_2f977_row2_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_2f977_row2_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_2f977_row3_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_2f977_row3_col1 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_2f977_row3_col2 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_2f977_row3_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_2f977_row3_col6 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_2f977_row3_col8, #T_2f977_row7_col3, #T_2f977_row7_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_2f977_row4_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_2f977_row4_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_2f977_row4_col5, #T_2f977_row7_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_2f977_row4_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_2f977_row4_col8, #T_2f977_row5_col8 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_2f977_row5_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_2f977_row5_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_2f977_row5_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_2f977_row5_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_2f977_row5_col4 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_2f977_row5_col6, #T_2f977_row5_col7 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_2f977_row6_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_2f977_row6_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_2f977_row6_col2 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_2f977_row6_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_2f977_row6_col4, #T_2f977_row7_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_2f977_row6_col5, #T_2f977_row7_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_2f977_row7_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_2f977_row7_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_2f977_row8_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_2f977_row8_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_2f977_row8_col2 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_2f977_row8_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_2f977_row8_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_2f977_row8_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_2f977_row8_col7 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# </style>
# <table id="T_2f977">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f977_level0_col0" class="col_heading level0 col0" >MedInc</th>
#       <th id="T_2f977_level0_col1" class="col_heading level0 col1" >HouseAge</th>
#       <th id="T_2f977_level0_col2" class="col_heading level0 col2" >AveRooms</th>
#       <th id="T_2f977_level0_col3" class="col_heading level0 col3" >AveBedrms</th>
#       <th id="T_2f977_level0_col4" class="col_heading level0 col4" >Population</th>
#       <th id="T_2f977_level0_col5" class="col_heading level0 col5" >AveOccup</th>
#       <th id="T_2f977_level0_col6" class="col_heading level0 col6" >Latitude</th>
#       <th id="T_2f977_level0_col7" class="col_heading level0 col7" >Longitude</th>
#       <th id="T_2f977_level0_col8" class="col_heading level0 col8" >MedHouseVal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f977_level0_row0" class="row_heading level0 row0" >MedInc</th>
#       <td id="T_2f977_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2f977_row0_col1" class="data row0 col1" >-0.119034</td>
#       <td id="T_2f977_row0_col2" class="data row0 col2" >0.326895</td>
#       <td id="T_2f977_row0_col3" class="data row0 col3" >-0.062040</td>
#       <td id="T_2f977_row0_col4" class="data row0 col4" >0.004834</td>
#       <td id="T_2f977_row0_col5" class="data row0 col5" >0.018766</td>
#       <td id="T_2f977_row0_col6" class="data row0 col6" >-0.079809</td>
#       <td id="T_2f977_row0_col7" class="data row0 col7" >-0.015176</td>
#       <td id="T_2f977_row0_col8" class="data row0 col8" >0.688075</td>
#     </tr>
#     <tr>
#       <th id="T_2f977_level0_row1" class="row_heading level0 row1" >HouseAge</th>
#       <td id="T_2f977_row1_col0" class="data row1 col0" >-0.119034</td>
#       <td id="T_2f977_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2f977_row1_col2" class="data row1 col2" >-0.153277</td>
#       <td id="T_2f977_row1_col3" class="data row1 col3" >-0.077747</td>
#       <td id="T_2f977_row1_col4" class="data row1 col4" >-0.296244</td>
#       <td id="T_2f977_row1_col5" class="data row1 col5" >0.013191</td>
#       <td id="T_2f977_row1_col6" class="data row1 col6" >0.011173</td>
#       <td id="T_2f977_row1_col7" class="data row1 col7" >-0.108197</td>
#       <td id="T_2f977_row1_col8" class="data row1 col8" >0.105623</td>
#     </tr>
#     <tr>
#       <th id="T_2f977_level0_row2" class="row_heading level0 row2" >AveRooms</th>
#       <td id="T_2f977_row2_col0" class="data row2 col0" >0.326895</td>
#       <td id="T_2f977_row2_col1" class="data row2 col1" >-0.153277</td>
#       <td id="T_2f977_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2f977_row2_col3" class="data row2 col3" >0.847621</td>
#       <td id="T_2f977_row2_col4" class="data row2 col4" >-0.072213</td>
#       <td id="T_2f977_row2_col5" class="data row2 col5" >-0.004852</td>
#       <td id="T_2f977_row2_col6" class="data row2 col6" >0.106389</td>
#       <td id="T_2f977_row2_col7" class="data row2 col7" >-0.027540</td>
#       <td id="T_2f977_row2_col8" class="data row2 col8" >0.151948</td>
#     </tr>
#     <tr>
#       <th id="T_2f977_level0_row3" class="row_heading level0 row3" >AveBedrms</th>
#       <td id="T_2f977_row3_col0" class="data row3 col0" >-0.062040</td>
#       <td id="T_2f977_row3_col1" class="data row3 col1" >-0.077747</td>
#       <td id="T_2f977_row3_col2" class="data row3 col2" >0.847621</td>
#       <td id="T_2f977_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2f977_row3_col4" class="data row3 col4" >-0.066197</td>
#       <td id="T_2f977_row3_col5" class="data row3 col5" >-0.006181</td>
#       <td id="T_2f977_row3_col6" cla

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
regr = LinearRegression(fit_intercept = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.33, random_state=42)

# %%
regr.fit(X_train,y_train);

# %%
regr.intercept_
# Out:
# -37.082010939079765

# %%
regr.coef_
# Out:
# array([ 4.44870466e-01,  9.55004561e-03, -1.21991503e-01,  7.79144696e-01,
#        -7.68990809e-08, -3.29948505e-03, -4.19131153e-01, -4.34103468e-01])

# %%
y_pred = regr.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.5295710106684457
